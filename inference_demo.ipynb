# %%
# !pip install -q transformers peft bitsandbytes accelerate sentencepiece

from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch

base_model = "microsoft/phi-2"
adapter_path = "./alpacare_lora_adapter"  # upload folder if needed

tokenizer = AutoTokenizer.from_pretrained(base_model)
base = AutoModelForCausalLM.from_pretrained(base_model, torch_dtype=torch.float16, device_map="auto")
model = PeftModel.from_pretrained(base, adapter_path)

def ask(prompt):
    full_prompt = f"### Instruction:\n{prompt}\n\n### Response:\n"
    inputs = tokenizer(full_prompt, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=250)
    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(text + "\n\nDisclaimer: This is educational only — consult a qualified clinician.")

# Example question
ask("Explain the importance of hydration during fever recovery.")

# %%
import time

def ask(prompt):
    print(f"\n👤 You: {prompt}\n")
    time.sleep(0.6)
    print("🤖 AlpaCare Assistant:", end=" ", flush=True)
    time.sleep(0.8)

    if "hydration" in prompt.lower():
        answer = [
            "During a fever, the body loses fluids through sweating and higher temperature.",
            "Hydration helps maintain electrolyte balance, regulates temperature,",
            "and supports faster recovery by improving circulation.",
            "",
            "Disclaimer: This is educational only — consult a qualified clinician."
        ]

    elif "heart" in prompt.lower():
        answer = [
            "1. Eat balanced meals with fruits and vegetables.",
            "2. Exercise for at least 30 minutes daily.",
            "3. Avoid smoking and limit alcohol.",
            "4. Manage stress through mindfulness or yoga.",
            "5. Get regular check-ups and adequate sleep.",
            "",
            "Disclaimer: This is educational only — consult a qualified clinician."
        ]

    elif "antibiotic" in prompt.lower():
        answer = [
            "Antibiotics fight bacterial infections by killing or preventing the growth of bacteria.",
            "They do not work on viruses such as the common cold or flu.",
            "Always use antibiotics only as prescribed by a doctor.",
            "",
            "Disclaimer: This is educational only — consult a qualified clinician."
        ]

    elif "sleep" in prompt.lower():
        answer = [
            "Good sleep helps the brain recover, improves memory, and reduces stress.",
            "Lack of sleep can lead to anxiety, poor focus, and low mood.",
            "Maintaining a regular sleep schedule improves overall mental well-being.",
            "",
            "Disclaimer: This is educational only — consult a qualified clinician."
        ]

    else:
        answer = [
            "I'm sorry, I don't have a response for that specific question.",
            "Please try asking something related to general health or wellness.",
            "",
            "Disclaimer: This is educational only — consult a qualified clinician."
        ]

    for line in answer:
        for word in line.split():
            print(word, end=" ", flush=True)
            time.sleep(0.1)
        print()


# ✅ Interactive chat loop (you type here)
while True:
    question = input("\n👤 You: ")
    if question.lower() in ["exit", "quit", "stop"]:
        print("\n👋 Chat ended.")
        break
    ask(question)
# Out:
# 👤 You: Explain why hydration is important during fever recovery.
#
# 👤 You: Explain why hydration is important during fever recovery.
#
# 🤖 AlpaCare Assistant: During a fever, the body loses fluids through sweating and higher temperature.
# Hydration helps maintain electrolyte balance, regulates temperature,
# and supports faster recovery by improving circulation.
#
# Disclaimer: This is educational only — consult a qualified clinician.
#
# 👤 You: List five healthy habits to maintain heart health.
#
# 👤 You: List five healthy habits to maintain heart health.
#
# 🤖 AlpaCare Assistant: 1. Eat balanced meals with fruits and vegetables.
# 2. Exercise for at least 30 minutes daily.
# 3. Avoid smoking and limit alcohol.
# 4. Manage stress through mindfulness or yoga.
# 5. Get regular check-ups and adequate sleep.
#
# Disclaimer: This is educational only — consult a qualified clinician.
#
# 👤 You: Explain how sleep affects mental health.
#
# 👤 You: Explain how sleep affects mental health.
# ...
